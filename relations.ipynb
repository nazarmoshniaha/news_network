# %%
import csv
import json
import pandas as pd
csv.field_size_limit(100000000)
csv.field_size_limit()

from datetime import datetime
from datetime import timedelta
from bs4 import BeautifulSoup
import re

# %%
df = pd.read_csv("ref_3.csv", header = 0, delimiter=',')

# %%
real_names = ['УНІАН', 'LB.ua', 'УП', 'Обозреватель', 'РБК', 'LIGA.net', 'ZIK',
                  'Сьогодні', '24 Канал', 'ТСН', 'Гордон', 'Апостроф', 'УНН',
                  'Фокус', 'Українські новини', 'Радіо Свобода', '112', 'Дзеркало тижня', 'Страна.ua',
                  'Знай', 'Факти', 'Політека', 'Інтерфакс', 'Громадське', 'Цензор.НЕТ', 'Еспресо ТВ']

# %%
df
# Out:
#                  Name  УНІАН  LB.ua   УП  Обозреватель   РБК  LIGA.net  ZIK  \
# 0               УНІАН      0     40  117           168   186        39    7
# 1               LB.ua      1      0   11             0    14         9    2
# 2                  УП      5      5    0             0    22        15    2
# 3        Обозреватель     37     24   50             0    66        29   16
# 4                 РБК      5      6    5             4     0        11    0
# 5            LIGA.net      5      8   15             1    17         0    0
# 6                 ZIK      0     10   44             6    89         8    0
# 7            Сьогодні      7     26   24             4    47        21    2
# 8            24 Канал     42     49  111            30   138        64    7
# 9                 ТСН     81     22   26            17    58        22    3
# 10             Гордон     21     56   83            98    87        20    4
# 11           Апостроф     20     11   33            86    60         9    9
# 12                УНН      0      1    6             0     0         9   21
# 13              Фокус      9     20   20             3    29        15    1
# 14  Українські новини     13     18   41            38    80        12    3
# 15      Радіо Свобода      4      2    4             1    10         3    0
# 16                112     12     13   52            16    80         8   13
# 17     Дзеркало тижня     17     12   22             5    28        15    0
# 18          Страна.ua     22     14   40            15    61        17   14
# 19               Знай     38     12   36            31    41        14   15
# 20              Факти     34     10   21             4    30         9    0
# 21           Політека     15     13   42           121   105         9   15
# 22          Інтерфакс      0      5   13             1     0         1    6
# 23         Громадське      8      8   33             0    25        25    3
# 24         Цензор.НЕТ    127     46   31            27   139        44    1
# 25         Еспресо ТВ     68     36   77             9   267        38    5
# 26               Сума    591    467  957           685  1679       466  149
# 27                NaN    127     56  117           168   267        64   21
#
#     Сьогодні  24 Канал  ...  Страна.ua  Знай  Факти  Політека  Інтерфакс  \
# 0         49        68  ...         22     4     24         0          6
# 1          0         0  ...          4     0      0         0         38
# 2          0         3  ...          0     0      0         0        151
# 3         18        16  ...         26     3     50         0         29
# 4          2         1  ...          0     2      0         0         10
# 5          1         0  ...          0     0      0         0          7
# 6          4         2  ...         29     3      0         0         25
# 7          0         4  ...          0    22      5         1         11
# 8         41         0  ...          7     7      4         0        112
# 9         12        10  ...          4    14     16         0         40
# 10        14        15  ...          9     5     19         1         38
# 11         9        14  ...         13    10      4         2         17
# 12         0         2  ...          0     2      0         0          0
# 13         6         3  ...          8     0      0         0          6
# 14        36        12  ...         75     1      8         0          9
# 15         2         1  ...          0     1      1         0         18
# 16        10         9  ...         27     5      3         0         32
# 17         1         4  ...          0     1      0         0         54
# 18        10        13  ...          0     0      2         1        221
# 19        30        15  ...          5     0      4        37          8
# 20         4         2  ...          0     3      0         0        108
# 21        72        36  ...         11    93      8         0          3
# 22         6         1  ...          0     1      0         0          0
# 23         5         6  ...          0     1      0         0         83
# 24        19        17  ...          0     1      4         1        669
# 25        14        25  ...          0     2      3         0        149
# 26       365       279  ...        240   181    155        43       1844
# 27        72        68  ...         75    93     50        37        669
#
#     Громадське  Цензор.НЕТ  Еспресо ТВ    Сума  Average
# 0          139          12           4  1837.0     71.0
# 1            2           5           0   119.0      5.0
# 2           61           1           0   404.0     16.0
# 3           25          22           9   693.0     27.0
# 4           23           4           0   189.0      7.0
# 5           22           5           0   124.0      5.0
# 6           39          13           2   419.0     16.0
# 7           23           6           0   294.0     11.0
# 8           84          19           6  1042.0     40.0
# 9           20           7           6   433.0     17.0
# 10          63          21           4   739.0     28.0
# 11          19          23           3   507.0     20.0
# 12           0           1           0   242.0      9.0
# 13          25           6           0   221.0      9.0
# 14          11          17           1   448.0     17.0
# 15           6           1           1    61.0      2.0
# 16          26           8           5   476.0     18.0
# 17          11           6           0   225.0      9.0
# 18          25           2           1   739.0     28.0
# 19          11          15           1   499.0     19.0
# 20          29           5           1   338.0     13.0
# 21           3          13           1   737.0     28.0
# 22           4           0           0    68.0      3.0
# 23           0           5           1   282.0     11.0
# 24          59           0           3  1410.0     54.0
# 25          98          40           0  1109.0     43.0
# 26         828         257          49     NaN      NaN
# 27         139          40           9     NaN      NaN
#
# [28 rows x 29 columns]

# %%
list_more_then_average = []

for i in range(len(df)-2):
    print(df.loc[i, 'Name'], '-', df.loc[i, 'Average'], 'середнє')

    for item in real_names:
        if df.loc[i, item] > df.loc[i, 'Average']:
            print('\t', item, '-', df.loc[i, item])
            list_more_then_average.append(item)
# Out:
# УНІАН - 71.0 середнє
# 	 УП - 117
# 	 Обозреватель - 168
# 	 РБК - 186
# 	 ТСН - 672
# 	 Радіо Свобода - 121
# 	 112 - 79
# 	 Громадське - 139
# LB.ua - 5.0 середнє
# 	 УП - 11
# 	 РБК - 14
# 	 LIGA.net - 9
# 	 Українські новини - 24
# 	 Інтерфакс - 38
# УП - 16.0 середнє
# 	 РБК - 22
# 	 Радіо Свобода - 115
# 	 Інтерфакс - 151
# 	 Громадське - 61
# Обозреватель - 27.0 середнє
# 	 УНІАН - 37
# 	 УП - 50
# 	 РБК - 66
# 	 LIGA.net - 29
# 	 ТСН - 60
# 	 Гордон - 75
# 	 Апостроф - 29
# 	 Українські новини - 31
# 	 Радіо Свобода - 47
# 	 Факти - 50
# 	 Інтерфакс - 29
# РБК - 7.0 середнє
# 	 LIGA.net - 11
# 	 Українські новини - 12
# 	 Радіо Свобода - 67
# 	 112 - 16
# 	 Інтерфакс - 10
# 	 Громадське - 23
# LIGA.net - 5.0 середнє
# 	 LB.ua - 8
# 	 УП - 15
# 	 РБК - 17
# 	 Радіо Свобода - 33
# 	 Інтерфакс - 7
# 	 Громадське - 22
# ZIK - 16.0 середнє
# 	 УП - 44
# 	 РБК - 89
# 	 УНН - 26
# 	 Радіо Свобода - 37
# 	 112 - 53
# 	 Страна.ua - 29
# 	 Інтерфакс - 25
# 	 Громадське - 39
# Сьогодні - 11.0 середнє
# 	 LB.ua - 26
# 	 УП - 24
# 	 РБК - 47
# 	 LIGA.net - 21
# 	 УНН - 14
# 	 Українські новини - 16
# 	 Радіо Свобода - 40
# 	 112 - 12
# 	 Знай - 22
# 	 Громадське - 23
# 24 Канал - 40.0 середнє
# 	 УНІАН - 42
# 	 LB.ua - 49
# 	 УП - 111
# 	 РБК - 138
# 	 LIGA.net - 64
# 	 Сьогодні - 41
# 	 ТСН - 98
# 	 Радіо Свобода - 126
# 	 Інтерфакс - 112
# 	 Громадське - 84
# ТСН - 17.0 середнє
# 	 УНІАН - 81
# 	 LB.ua - 22
# 	 УП - 26
# 	 РБК - 58
# 	 LIGA.net - 22
# 	 Радіо Свобода - 36
# 	 Інтерфакс - 40
# 	 Громадське - 20
# Гордон - 28.0 середнє
# 	 LB.ua - 56
# 	 УП - 83
# 	 Обозреватель - 98
# 	 РБК - 87
# 	 Українські новини - 36
# 	 Радіо Свобода - 73
# 	 Інтерфакс - 38
# 	 Громадське - 63
# Апостроф - 20.0 середнє
# 	 УП - 33
# 	 Обозреватель - 86
# 	 РБК - 60
# 	 ТСН - 49
# 	 Українські новини - 46
# 	 Радіо Свобода - 38
# 	 Цензор.НЕТ - 23
# УНН - 9.0 середнє
# 	 ZIK - 21
# 	 Радіо Свобода - 176
# 	 112 - 13
# Фокус - 9.0 середнє
# 	 LB.ua - 20
# 	 УП - 20
# 	 РБК - 29
# 	 LIGA.net - 15
# 	 ТСН - 17
# 	 Радіо Свобода - 19
# 	 Громадське - 25
# Українські новини - 17.0 середнє
# 	 LB.ua - 18
# 	 УП - 41
# 	 Обозреватель - 38
# 	 РБК - 80
# 	 Сьогодні - 36
# 	 Радіо Свобода - 21
# 	 112 - 26
# 	 Страна.ua - 75
# Радіо Свобода - 2.0 середнє
# 	 УНІАН - 4
# 	 УП - 4
# 	 РБК - 10
# 	 LIGA.net - 3
# 	 112 - 3
# 	 Інтерфакс - 18
# 	 Громадське - 6
# 112 - 18.0 середнє
# 	 УП - 52
# 	 РБК - 80
# 	 УНН - 32
# 	 Українські новини - 41
# 	 Радіо Свобода - 61
# 	 Страна.ua - 27
# 	 Інтерфакс - 32
# 	 Громадське - 26
# Дзеркало тижня - 9.0 середнє
# 	 УНІАН - 17
# 	 LB.ua - 12
# 	 УП - 22
# 	 РБК - 28
# 	 LIGA.net - 15
# 	 Українські новини - 11
# 	 Радіо Свобода - 20
# 	 Інтерфакс - 54
# 	 Громадське - 11
# Страна.ua - 28.0 середнє
# 	 УП - 40
# 	 РБК - 61
# 	 ТСН - 47
# 	 Українські новини - 122
# 	 Радіо Свобода - 42
# 	 112 - 33
# 	 Інтерфакс - 221
# Знай - 19.0 середнє
# 	 УНІАН - 38
# 	 УП - 36
# 	 Обозреватель - 31
# 	 РБК - 41
# 	 Сьогодні - 30
# 	 ТСН - 70
# 	 Українські новини - 20
# 	 Радіо Свобода - 22
# 	 112 - 35
# 	 Політека - 37
# Факти - 13.0 середнє
# 	 УНІАН - 34
# 	 УП - 21
# 	 РБК - 30
# 	 Українські новини - 16
# 	 Радіо Свобода - 34
# 	 Інтерфакс - 108
# 	 Громадське - 29
# Політека - 28.0 середнє
# 	 УП - 42
# 	 Обозреватель - 121
# 	 РБК - 105
# 	 Сьогодні - 72
# 	 24 Канал - 36
# 	 ТСН - 34
# 	 Апостроф - 63
# 	 Знай - 93
# Інтерфакс - 3.0 середнє
# 	 LB.ua - 5
# 	 УП - 13
# 	 ZIK - 6
# 	 Сьогодні - 6
# 	 ТСН - 5
# 	 Радіо Свобода - 13
# 	 112 - 9
# 	 Громадське - 4
# Громадське - 11.0 середнє
# 	 УП - 33
# 	 РБК - 25
# 	 LIGA.net - 25
# 	 Радіо Свобода - 54
# 	 Інтерфакс - 83
# Цензор.НЕТ - 54.0 середнє
# 	 УНІАН - 127
# 	 РБК - 139
# 	 Радіо Свобода - 126
# 	 Інтерфакс - 669
# 	 Громадське - 59
# Еспресо ТВ - 43.0 середнє
# 	 УНІАН - 68
# 	 УП - 77
# 	 РБК - 267
# 	 Радіо Свобода - 215
# 	 Інтерфакс - 149
# 	 Громадське - 98

# %%
for name in real_names:
    print(name, '-', list_more_then_average.count(name))
# Out:
# УНІАН - 9
# LB.ua - 9
# УП - 22
# Обозреватель - 6
# РБК - 23
# LIGA.net - 10
# ZIK - 2
# Сьогодні - 5
# 24 Канал - 1
# ТСН - 9
# Гордон - 1
# Апостроф - 2
# УНН - 3
# Фокус - 0
# Українські новини - 11
# Радіо Свобода - 23
# 112 - 10
# Дзеркало тижня - 0
# Страна.ua - 3
# Знай - 2
# Факти - 1
# Політека - 1
# Інтерфакс - 17
# Громадське - 17
# Цензор.НЕТ - 1
# Еспресо ТВ - 0
